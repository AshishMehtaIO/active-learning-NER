# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set()

# %%
dir = os.getcwd()+'/Results/ESP/'
labels = ['Uncertainity Least Confidence', 'Uncertainity Total Entropy', 'Baseline Max length', 'QBC 3 Learners', 'Baseline Random']
for iter, filename in enumerate(sorted(os.listdir(dir))):
    print(filename)
    data = np.loadtxt(dir+filename)
    x = data[:,0]
    y = data[:,1]
    plt.plot(x,y, label=labels[iter])
    plt.legend()
    plt.ylabel('F1 score')
    plt.xlabel('Number of sentences in training set')
    plt.title('Learning Curve for Active Learning starategies on ESP CONLL2002 dataset')
    plt.savefig('ESP.png', dpi=600)
# Out:
# ESP_LC.txt
# ESP_TTE.txt
# ESP_maxlen.txt
# ESP_qbc3learner.txt
# ESP_random.txt

# %%
dir = os.getcwd()+'/Results/ESP/'
labels = ['Uncertainity Least Confidence', 'Uncertainity Total Entropy', 'Baseline Max length', 'QBC 3 Learners', 'Baseline Random']

threshold = 0.7

for iter, filename in enumerate(sorted(os.listdir(dir))):
    x=[]
    y=[]
    print(filename)
    data = np.loadtxt(dir+filename)
    for d in data:
        if d[1] < threshold:
            x.append(d[0])
            y.append(d[1])
    print(x[-1])
    plt.plot(x,y, label=labels[iter])
    plt.legend()
    plt.ylabel('F1 score')
    plt.xlabel('Number of sentences in training set')
    plt.title('Learning Curve for Active Learning starategies on ESP CONLL2002 dataset')
    plt.savefig('ESP_thresh.png', dpi=600)
# Out:
# ESP_LC.txt
# 780.0
# ESP_TTE.txt
# 460.0
# ESP_maxlen.txt
# 1100.0
# ESP_qbc3learner.txt
# 920.0
# ESP_random.txt
# 2360.0

# %%
dir = os.getcwd()+'/Results/ENG_power2/'
labels = ['QBC 10 learners', 'QBC 3 learners']
# labels = ['Uncertainity Least Confidence', 'Uncertainity Total Entropy', 'Baseline Max length', 'QBC 3 Learners', 'Baseline Random']
for iter, filename in enumerate(sorted(os.listdir(dir))):
    print(filename)
    data = np.loadtxt(dir+filename)
    x = data[:,0]
    y = data[:,1]
    plt.plot(x,y, label=labels[iter])
    plt.legend()
    plt.ylabel('F1 score')
    plt.xlabel('Number of sentences in training set')
    plt.title('Learning curve for varying committe size on CONLL2003 dataset')
    plt.savefig('ENG_pow2.png', dpi=600)
# Out:
# ENG_qbc10learner_power2.txt
# ENG_qbc3learner_power2.txt

# %%
dir = os.getcwd()+'/Results/ENG/'
labels = ['Uncertainity Least Confidence', 'Uncertainity Total Entropy', 'Baseline Max length', 'QBC 3 Learners', 'Baseline Random']
for iter, filename in enumerate(sorted(os.listdir(dir))):
    x=[]
    y=[]
    print(filename)
    data = np.loadtxt(dir+filename)
    for d in data:
        if d[0] < 7000:
            x.append(d[0])
            y.append(d[1])
    plt.plot(x,y, label=labels[iter])
    plt.legend()
    plt.ylabel('F1 score')
    plt.xlabel('Number of sentences in training set')
    plt.title('Learning Curve for Active Learning starategies on ENG CONLL2003 dataset')
    plt.savefig('ENG.png', dpi=600)
# Out:
# ENG_LC.txt
# ENG_TTE.txt
# ENG_maxlen.txt
# ENG_qbc3learner.txt
# ENG_random.txt

# %%
dir = os.getcwd()+'/Results/ENG/'
labels = ['Uncertainity Least Confidence', 'Uncertainity Total Entropy', 'Baseline Max length', 'QBC 3 Learners', 'Baseline Random']

threshold = 0.5

for iter, filename in enumerate(sorted(os.listdir(dir))):
    x=[]
    y=[]
    print(filename)
    data = np.loadtxt(dir+filename)
    for d in data:
        if d[1] < threshold:
            x.append(d[0])
            y.append(d[1])
    print(x[-1])
    plt.plot(x,y, label=labels[iter])
    plt.legend()
    plt.ylabel('F1 score')
    plt.xlabel('Number of sentences in training set')
    plt.title('Learning Curve for Active Learning starategies on ENG CONLL2003 dataset')
    plt.savefig('ENG_thresh.png', dpi=600)
# Out:
# ENG_LC.txt
# 2040.0
# ENG_TTE.txt
# 1440.0
# ENG_maxlen.txt
# 6600.0
# ENG_qbc3learner.txt
# 2400.0
# ENG_random.txt
# 6220.0
